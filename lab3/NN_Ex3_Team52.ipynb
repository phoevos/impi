# %% [markdown]
# # Βαθιά μάθηση στο CIFAR-100

# %% [markdown]
# ## Εισαγωγή και επισκόπηση του συνόλου δεδομένων

# %%
from __future__ import absolute_import, division, print_function, unicode_literals # legacy compatibility

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# helper functions

# select from from_list elements with index in index_list
def select_from_list(from_list, index_list):
  filtered_list= [from_list[i] for i in index_list]
  return(filtered_list)

# append in filtered_list the index of each element of unfilterd_list if it exists in target_list
def get_ds_index(unfiliterd_list, target_list):
  index = 0
  filtered_list=[]
  for i_ in unfiliterd_list:
    if i_[0] in target_list:
      filtered_list.append(index)
    index += 1
  return(filtered_list)

# select a url for a unique subset of CIFAR-100 with 20, 40, 60, or 80 classes
def select_classes_number(classes_number = 20):
  cifar100_20_classes_url = "https://pastebin.com/raw/nzE1n98V"
  cifar100_40_classes_url = "https://pastebin.com/raw/zGX4mCNP"
  cifar100_60_classes_url = "https://pastebin.com/raw/nsDTd3Qn"
  cifar100_80_classes_url = "https://pastebin.com/raw/SNbXz700"
  if classes_number == 20:
    return cifar100_20_classes_url
  elif classes_number == 40:
    return cifar100_40_classes_url
  elif classes_number == 60:
    return cifar100_60_classes_url
  elif classes_number == 80:
    return cifar100_80_classes_url
  else:
    return -1

# %%
# load the entire dataset
(x_train_all, y_train_all), (x_test_all, y_test_all) = tf.keras.datasets.cifar100.load_data(label_mode='fine')

# %%
print(x_train_all.shape)
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# Η κάθε ομάδα θα δουλέψει με ένα μοναδικό ξεχωριστό υποσύνολο του CIFAR-100
# Στο επόμενο κελί, αντικαταστήστε την τιμή της μεταβλητής `team_seed` με τον αριθμό της ομάδας σας.

# %%
# REPLACE WITH YOUR TEAM NUMBER
team_seed = 52

# %% [markdown]
# Στο επόμενο κελί μπορείτε να διαλέξετε το πλήθος των κατηγορίων σας: 20 (default), 40, 60 ή 80.

# %%
# select the number of classes
cifar100_classes_url = select_classes_number(80)

# %% [markdown]
# Δημιουργούμε το μοναδικό dataset της ομάδας μας:

# %%
team_classes = pd.read_csv(cifar100_classes_url, sep=',', header=None)
CIFAR100_LABELS_LIST = pd.read_csv('https://pastebin.com/raw/qgDaNggt', sep=',', header=None).astype(str).values.tolist()[0]

our_index = team_classes.iloc[team_seed,:].values.tolist()
our_classes = select_from_list(CIFAR100_LABELS_LIST, our_index)
train_index = get_ds_index(y_train_all, our_index)
test_index = get_ds_index(y_test_all, our_index)

x_train_ds = np.asarray(select_from_list(x_train_all, train_index))
y_train_ds = np.asarray(select_from_list(y_train_all, train_index))
x_test_ds = np.asarray(select_from_list(x_test_all, test_index))
y_test_ds = np.asarray(select_from_list(y_test_all, test_index))

# %%
# print our classes
print(our_classes)
# Out:
# ['apple', ' aquarium_fish', ' baby', ' bear', ' bed', ' beetle', ' bicycle', ' bottle', ' bowl', ' boy', ' bus', ' butterfly', ' camel', ' castle', ' caterpillar', ' cattle', ' chair', ' chimpanzee', ' clock', ' couch', ' crab', ' crocodile', ' cup', ' dinosaur', ' dolphin', ' elephant', ' flatfish', ' forest', ' girl', ' hamster', ' house', ' kangaroo', ' keyboard', ' lamp', ' lawn_mower', ' leopard', ' lion', ' lobster', ' maple_tree', ' motorcycle', ' mouse', ' oak_tree', ' otter', ' palm_tree', ' pear', ' pickup_truck', ' pine_tree', ' plain', ' plate', ' poppy', ' porcupine', ' possum', ' rabbit', ' raccoon', ' ray', ' road', ' rocket', ' rose', ' sea', ' seal', ' skyscraper', ' snail', ' snake', ' spider', ' squirrel', ' sunflower', ' sweet_pepper', ' table', ' tank', ' television', ' tiger', ' tractor', ' train', ' tulip', ' turtle', ' wardrobe', ' whale', ' willow_tree', ' wolf', ' woman']

# %%
CLASSES_NUM=len(our_classes)

# %%
print(x_train_ds[1].shape)
# Out:
# (32, 32, 3)

# %%
# get (train) dataset dimensions
data_size, img_rows, img_cols, img_channels = x_train_ds.shape

# set validation set percentage (wrt the training set size)
validation_percentage = 0.15
val_size = round(validation_percentage * data_size)

# Reserve val_size samples for validation and normalize all values
x_val = x_train_ds[-val_size:]/255
y_val = y_train_ds[-val_size:]
x_train = x_train_ds[:-val_size]/255
y_train = y_train_ds[:-val_size]
x_test = x_test_ds/255
y_test = y_test_ds

print(len(x_val))

# summarize loaded dataset
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

# get class label from class index
def class_label_from_index(fine_category):
  return(CIFAR100_LABELS_LIST[fine_category.item(0)])

# plot first few images
plt.figure(figsize=(6, 6))
for i in range(9):
	# define subplot
  plt.subplot(330 + 1 + i).set_title(class_label_from_index(y_train[i]))
	# plot raw pixel data
  plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
  #show the figure
plt.show()
# Out:
# 6000
# Train: X=(34000, 32, 32, 3), y=(34000, 1)
# Validation: X=(6000, 32, 32, 3), y=(6000, 1)
# Test: X=(8000, 32, 32, 3), y=(8000, 1)

# %%
# find unique labels using a dict -- key: real label, value: transformed label
labels = {}
for i,label in enumerate(np.unique(y_train)):
    labels[label] = i

print(labels)

# transform y sets
y_train = [labels[int(label)] for label in y_train]
y_val = [labels[int(label)] for label in y_val]
y_test = [labels[int(label)] for label in y_test]
# Out:
# {0: 0, 1: 1, 2: 2, 3: 3, 5: 4, 7: 5, 8: 6, 9: 7, 10: 8, 11: 9, 13: 10, 14: 11, 15: 12, 17: 13, 18: 14, 19: 15, 20: 16, 21: 17, 22: 18, 25: 19, 26: 20, 27: 21, 28: 22, 29: 23, 30: 24, 31: 25, 32: 26, 33: 27, 35: 28, 36: 29, 37: 30, 38: 31, 39: 32, 40: 33, 41: 34, 42: 35, 43: 36, 45: 37, 47: 38, 48: 39, 50: 40, 52: 41, 55: 42, 56: 43, 57: 44, 58: 45, 59: 46, 60: 47, 61: 48, 62: 49, 63: 50, 64: 51, 65: 52, 66: 53, 67: 54, 68: 55, 69: 56, 70: 57, 71: 58, 72: 59, 76: 60, 77: 61, 78: 62, 79: 63, 80: 64, 82: 65, 83: 66, 84: 67, 85: 68, 87: 69, 88: 70, 89: 71, 90: 72, 92: 73, 93: 74, 94: 75, 95: 76, 96: 77, 97: 78, 98: 79}

# %% [markdown]
# ## Συναρτήσεις εκπαίδευσης

# %% [markdown]
# Θα χρησιμοποιήσουμε την ιδιότητα data prefetch του tf2:

# %%
# we user prefetch https://www.tensorflow.org/api_docs/python/tf/data/Dataset#prefetch 
# see also AUTOTUNE
# the dataset is now "infinite"

BATCH_SIZE = 128
AUTOTUNE = tf.data.experimental.AUTOTUNE # https://www.tensorflow.org/guide/data_performance

def _input_fn(x, y, BATCH_SIZE, shuffle=None):
    ds = tf.data.Dataset.from_tensor_slices((x,y))
    ds = ds.shuffle(buffer_size=data_size, reshuffle_each_iteration=shuffle)
    ds = ds.repeat() 
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

datagen = ImageDataGenerator(
    rotation_range=45,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.5,
    horizontal_flip=True,
)
datagen.fit(x_train)

# train_ds =_input_fn(x_train,y_train, BATCH_SIZE) #PrefetchDataset object
train_ds = datagen.flow(x=x_train, y=y_train, batch_size=BATCH_SIZE, shuffle=True)
validation_ds =_input_fn(x_val, y_val, BATCH_SIZE, shuffle=False) 
test_ds =_input_fn(x_test, y_test, BATCH_SIZE, shuffle=False) 

# steps_per_epoch and validation_steps for training and validation: https://www.tensorflow.org/guide/keras/train_and_evaluate

def train_model(model, epochs = 10, steps_per_epoch = 2, validation_steps = 1):
  early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=20, restore_best_weights=True)
  history = model.fit(train_ds, steps_per_epoch=len(x_train)//BATCH_SIZE, epochs=epochs, validation_data=validation_ds, validation_steps=len(x_val)//BATCH_SIZE, callbacks=[early_stop]) #len(x_val)/BATCH_SIZE , callbacks=[early_stop]
  return history

# %% [markdown]
# ## Γραφικές παραστάσεις εκπαίδευσης και απόδοση στο σύνολο ελέγχου

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
	plt.figure(figsize=(8, 8))
	plt.suptitle('Training Curves')
	# plot loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='val')
	plt.legend(loc='upper right')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='val')
	plt.legend(loc='lower right')
	return plt
 
# print test set evaluation metrics
def model_evaluation(model, evaluation_steps):
	print('\nTest set evaluation metrics')
	loss0, accuracy0 = model.evaluate(test_ds, steps=evaluation_steps)
	print("loss: {:.2f}".format(loss0))
	print("accuracy: {:.2f}".format(accuracy0))

def model_report(model, history, evaluation_steps=10):
	plt = summarize_diagnostics(history)
	plt.show()
	model_evaluation(model, evaluation_steps)

# %% [markdown]
# ## Βελτιστοποιημένα Μοντέλα Δικτύων

# %% [markdown]
# ### Συνελικτικό δίκτυο "From Scratch"

# %%
# a simple CNN https://www.tensorflow.org/tutorials/images/cnn

def init_simple_model(summary):
  model = models.Sequential()
  model.add(layers.Conv2D(64, (3, 3), activation='elu', input_shape=(32,32,3)))
  model.add(layers.Conv2D(64, (3, 3), activation='elu'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))

  model.add(layers.Conv2D(128, (3, 3), activation='elu'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.3))

  model.add(layers.Conv2D(256, (3, 3), activation='elu'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.3))

  model.add(layers.Flatten())
  model.add(layers.Dense(1024, activation='elu'))
  model.add(layers.Dense(100, activation='softmax'))
  
  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

# %%
SIMPLE_MODEL = init_simple_model(summary = True)
SIMPLE_MODEL_history = train_model(SIMPLE_MODEL, 500, 30, 5)
SIMPLE_MODEL_report = model_report(SIMPLE_MODEL, SIMPLE_MODEL_history, 30)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 30, 30, 64)        1792
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dense_15 (Dense)             (None, 100)               102500
# =================================================================
# Total params: 1,561,636
# Trainable params: 1,560,740
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/500
# 265/265 [==============================] - 18s 65ms/step - loss: 4.5140 - accuracy: 0.0566 - val_loss: 4.6779 - val_accuracy: 0.0328
# Epoch 2/500
# 265/265 [==============================] - 17s 64ms/step - loss: 3.7655 - accuracy: 0.1141 - val_loss: 3.4504 - val_accuracy: 0.1736
# Epoch 3/500
# 265/265 [==============================] - 17s 64ms/step - loss: 3.5656 - accuracy: 0.1495 - val_loss: 3.3397 - val_accuracy: 0.1856
# Epoch 4/500
# 265/265 [==============================] - 17s 64ms/step - loss: 3.4444 - accuracy: 0.1655 - val_loss: 3.0852 - val_accuracy: 0.2400
# Epoch 5/500
# 265/265 [==============================] - 17s 64ms/step - loss: 3.3223 - accuracy: 0.1861 - val_loss: 3.1038 - val_accuracy: 0.2410
# Epoch 6/500
# 265/265 [==============================] - 17s 64ms/step - loss: 3.2638 - accuracy: 0.1971 - val_loss: 2.9500 - val_accuracy: 0.2672
# Epoch 7/500
# 265/265 [==============================] - 17s 64ms/step - loss: 3.1944 - accuracy: 0.2128 - val_loss: 3.0178 - val_accuracy: 0.2480
# Epoch 8/500
# 265/265 [==============================] - 17s 64ms/step - loss: 3.1678 - accuracy: 0.2133 - val_loss: 2.9299 - val_accuracy: 0.2729
# Epoch 9/500
# 265/265 [==============================] - 17s 63ms/step - loss: 3.1006 - accuracy: 0.2272 - val_loss: 2.9173 - val_accuracy: 0.2787
# Epoch 10/500
# 265/265 [==============================] - 17s 63ms/step - loss: 3.0653 - accuracy: 0.2347 - val_loss: 2.9246 - val_accuracy: 0.2767
# Epoch 11/500
# 265/265 [==============================] - 17s 63ms/step - loss: 3.0461 - accuracy: 0.2391 - val_loss: 2.7671 - val_accuracy: 0.3016
# Epoch 12/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.9817 - accuracy: 0.2501 - val_loss: 2.7573 - val_accuracy: 0.3081
# Epoch 13/500
# 265/265 [==============================] - 17s 65ms/step - loss: 2.9456 - accuracy: 0.2586 - val_loss: 2.7082 - val_accuracy: 0.3179
# Epoch 14/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.9170 - accuracy: 0.2610 - val_loss: 2.8081 - val_accuracy: 0.3035
# Epoch 15/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.8633 - accuracy: 0.2717 - val_loss: 2.5509 - val_accuracy: 0.3438
# Epoch 16/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.8300 - accuracy: 0.2805 - val_loss: 2.6925 - val_accuracy: 0.3173
# Epoch 17/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.8141 - accuracy: 0.2758 - val_loss: 2.5280 - val_accuracy: 0.3522
# Epoch 18/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.8095 - accuracy: 0.2825 - val_loss: 2.5225 - val_accuracy: 0.3490
# Epoch 19/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.7914 - accuracy: 0.2912 - val_loss: 2.5348 - val_accuracy: 0.3482
# Epoch 20/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.7272 - accuracy: 0.3018 - val_loss: 2.5390 - val_accuracy: 0.3499
# Epoch 21/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.7197 - accuracy: 0.3009 - val_loss: 2.4275 - val_accuracy: 0.3696
# Epoch 22/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.6996 - accuracy: 0.3041 - val_loss: 2.4466 - val_accuracy: 0.3657
# Epoch 23/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.6568 - accuracy: 0.3137 - val_loss: 2.4020 - val_accuracy: 0.3713
# Epoch 24/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.6455 - accuracy: 0.3146 - val_loss: 2.4382 - val_accuracy: 0.3670
# Epoch 25/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.6195 - accuracy: 0.3248 - val_loss: 2.4248 - val_accuracy: 0.3726
# Epoch 26/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.6050 - accuracy: 0.3262 - val_loss: 2.3901 - val_accuracy: 0.3803
# Epoch 27/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.5835 - accuracy: 0.3344 - val_loss: 2.3654 - val_accuracy: 0.3882
# Epoch 28/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.5678 - accuracy: 0.3326 - val_loss: 2.3060 - val_accuracy: 0.4015
# Epoch 29/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.5598 - accuracy: 0.3367 - val_loss: 2.2779 - val_accuracy: 0.4020
# Epoch 30/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.5426 - accuracy: 0.3402 - val_loss: 2.3686 - val_accuracy: 0.3867
# Epoch 31/500
# 265/265 [==============================] - 17s 65ms/step - loss: 2.5104 - accuracy: 0.3483 - val_loss: 2.3472 - val_accuracy: 0.3915
# Epoch 32/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.5087 - accuracy: 0.3487 - val_loss: 2.2505 - val_accuracy: 0.4134
# Epoch 33/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.4712 - accuracy: 0.3573 - val_loss: 2.2382 - val_accuracy: 0.4181
# Epoch 34/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.4741 - accuracy: 0.3596 - val_loss: 2.1930 - val_accuracy: 0.4271
# Epoch 35/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.4420 - accuracy: 0.3613 - val_loss: 2.2421 - val_accuracy: 0.4137
# Epoch 36/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.4114 - accuracy: 0.3634 - val_loss: 2.2448 - val_accuracy: 0.4147
# Epoch 37/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.4013 - accuracy: 0.3686 - val_loss: 2.2491 - val_accuracy: 0.4141
# Epoch 38/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.3997 - accuracy: 0.3743 - val_loss: 2.1891 - val_accuracy: 0.4331
# Epoch 39/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.3756 - accuracy: 0.3731 - val_loss: 2.2086 - val_accuracy: 0.4226
# Epoch 40/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.3521 - accuracy: 0.3824 - val_loss: 2.1493 - val_accuracy: 0.4372
# Epoch 41/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.3473 - accuracy: 0.3820 - val_loss: 2.1423 - val_accuracy: 0.4375
# Epoch 42/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.3390 - accuracy: 0.3877 - val_loss: 2.1935 - val_accuracy: 0.4290
# Epoch 43/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.3257 - accuracy: 0.3851 - val_loss: 2.1504 - val_accuracy: 0.4399
# Epoch 44/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.2945 - accuracy: 0.3933 - val_loss: 2.1346 - val_accuracy: 0.4450
# Epoch 45/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.2725 - accuracy: 0.3999 - val_loss: 2.0890 - val_accuracy: 0.4536
# Epoch 46/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.2699 - accuracy: 0.4001 - val_loss: 2.1154 - val_accuracy: 0.4509
# Epoch 47/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.2555 - accuracy: 0.4017 - val_loss: 2.0988 - val_accuracy: 0.4528
# Epoch 48/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.2392 - accuracy: 0.4059 - val_loss: 2.0536 - val_accuracy: 0.4643
# Epoch 49/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.2343 - accuracy: 0.4040 - val_loss: 2.0425 - val_accuracy: 0.4659
# Epoch 50/500
# 265/265 [==============================] - 17s 65ms/step - loss: 2.2357 - accuracy: 0.4098 - val_loss: 2.0560 - val_accuracy: 0.4565
# Epoch 51/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.2216 - accuracy: 0.4085 - val_loss: 2.0980 - val_accuracy: 0.4577
# Epoch 52/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.1959 - accuracy: 0.4119 - val_loss: 2.0259 - val_accuracy: 0.4650
# Epoch 53/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.1846 - accuracy: 0.4161 - val_loss: 2.0034 - val_accuracy: 0.4721
# Epoch 54/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.1722 - accuracy: 0.4215 - val_loss: 2.0342 - val_accuracy: 0.4589
# Epoch 55/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.1548 - accuracy: 0.4232 - val_loss: 2.0005 - val_accuracy: 0.4679
# Epoch 56/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.1683 - accuracy: 0.4254 - val_loss: 2.0360 - val_accuracy: 0.4635
# Epoch 57/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.1398 - accuracy: 0.4294 - val_loss: 2.0140 - val_accuracy: 0.4711
# Epoch 58/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.1184 - accuracy: 0.4329 - val_loss: 1.9926 - val_accuracy: 0.4769
# Epoch 59/500
# 265/265 [==============================] - 17s 63ms/step - loss: 2.1211 - accuracy: 0.4321 - val_loss: 2.0126 - val_accuracy: 0.4720
# Epoch 60/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.1199 - accuracy: 0.4301 - val_loss: 1.9990 - val_accuracy: 0.4762
# Epoch 61/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.0929 - accuracy: 0.4367 - val_loss: 2.0495 - val_accuracy: 0.4642
# Epoch 62/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.0938 - accuracy: 0.4375 - val_loss: 1.9621 - val_accuracy: 0.4834
# Epoch 63/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.0873 - accuracy: 0.4336 - val_loss: 1.9690 - val_accuracy: 0.4789
# Epoch 64/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.0905 - accuracy: 0.4398 - val_loss: 1.9239 - val_accuracy: 0.4951
# Epoch 65/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.0736 - accuracy: 0.4395 - val_loss: 1.9640 - val_accuracy: 0.4822
# Epoch 66/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.0629 - accuracy: 0.4432 - val_loss: 1.9302 - val_accuracy: 0.4896
# Epoch 67/500
# 265/265 [==============================] - 17s 65ms/step - loss: 2.0486 - accuracy: 0.4460 - val_loss: 1.9128 - val_accuracy: 0.4983
# Epoch 68/500
# 265/265 [==============================] - 17s 65ms/step - loss: 2.0411 - accuracy: 0.4515 - val_loss: 1.9388 - val_accuracy: 0.4890
# Epoch 69/500
# 265/265 [==============================] - 17s 65ms/step - loss: 2.0274 - accuracy: 0.4536 - val_loss: 1.9188 - val_accuracy: 0.4993
# Epoch 70/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.0287 - accuracy: 0.4557 - val_loss: 1.9426 - val_accuracy: 0.4878
# Epoch 71/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.0090 - accuracy: 0.4584 - val_loss: 1.9111 - val_accuracy: 0.4949
# Epoch 72/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.0154 - accuracy: 0.4538 - val_loss: 1.9386 - val_accuracy: 0.4915
# Epoch 73/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.9795 - accuracy: 0.4685 - val_loss: 1.8828 - val_accuracy: 0.5005
# Epoch 74/500
# 265/265 [==============================] - 17s 64ms/step - loss: 2.0072 - accuracy: 0.4560 - val_loss: 1.9518 - val_accuracy: 0.4868
# Epoch 75/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.9830 - accuracy: 0.4637 - val_loss: 1.8974 - val_accuracy: 0.5015
# Epoch 76/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.9525 - accuracy: 0.4724 - val_loss: 1.9167 - val_accuracy: 0.4983
# Epoch 77/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.9600 - accuracy: 0.4672 - val_loss: 1.8776 - val_accuracy: 0.5048
# Epoch 78/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.9591 - accuracy: 0.4675 - val_loss: 1.8999 - val_accuracy: 0.4997
# Epoch 79/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.9461 - accuracy: 0.4696 - val_loss: 1.8467 - val_accuracy: 0.5114
# Epoch 80/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.9465 - accuracy: 0.4738 - val_loss: 1.8544 - val_accuracy: 0.5083
# Epoch 81/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.9446 - accuracy: 0.4758 - val_loss: 1.9120 - val_accuracy: 0.5019
# Epoch 82/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.9273 - accuracy: 0.4804 - val_loss: 1.9093 - val_accuracy: 0.4998
# Epoch 83/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.9152 - accuracy: 0.4800 - val_loss: 1.8623 - val_accuracy: 0.5121
# Epoch 84/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.9264 - accuracy: 0.4788 - val_loss: 1.8422 - val_accuracy: 0.5182
# Epoch 85/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.9225 - accuracy: 0.4765 - val_loss: 1.9120 - val_accuracy: 0.5003
# Epoch 86/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.9063 - accuracy: 0.4806 - val_loss: 1.8548 - val_accuracy: 0.5117
# Epoch 87/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.8917 - accuracy: 0.4830 - val_loss: 1.8367 - val_accuracy: 0.5124
# Epoch 88/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.8826 - accuracy: 0.4877 - val_loss: 1.8814 - val_accuracy: 0.5031
# Epoch 89/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.8558 - accuracy: 0.4916 - val_loss: 1.8480 - val_accuracy: 0.5115
# Epoch 90/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.8633 - accuracy: 0.4899 - val_loss: 1.8396 - val_accuracy: 0.5146
# Epoch 91/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.8569 - accuracy: 0.4930 - val_loss: 1.8297 - val_accuracy: 0.5138
# Epoch 92/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.8476 - accuracy: 0.4973 - val_loss: 1.8078 - val_accuracy: 0.5212
# Epoch 93/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.8333 - accuracy: 0.4971 - val_loss: 1.8250 - val_accuracy: 0.5192
# Epoch 94/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.8234 - accuracy: 0.5022 - val_loss: 1.8547 - val_accuracy: 0.5153
# Epoch 95/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.8175 - accuracy: 0.5006 - val_loss: 1.8246 - val_accuracy: 0.5166
# Epoch 96/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.8191 - accuracy: 0.5001 - val_loss: 1.8462 - val_accuracy: 0.5136
# Epoch 97/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.8115 - accuracy: 0.5015 - val_loss: 1.8573 - val_accuracy: 0.5156
# Epoch 98/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.8208 - accuracy: 0.5024 - val_loss: 1.8661 - val_accuracy: 0.5119
# Epoch 99/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.8057 - accuracy: 0.4993 - val_loss: 1.7804 - val_accuracy: 0.5233
# Epoch 100/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.8013 - accuracy: 0.5029 - val_loss: 1.7952 - val_accuracy: 0.5250
# Epoch 101/500
# 265/265 [==============================] - 17s 63ms/step - loss: 1.7749 - accuracy: 0.5125 - val_loss: 1.7851 - val_accuracy: 0.5287
# Epoch 102/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.7834 - accuracy: 0.5096 - val_loss: 1.8128 - val_accuracy: 0.5219
# Epoch 103/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.7799 - accuracy: 0.5093 - val_loss: 1.8022 - val_accuracy: 0.5236
# Epoch 104/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.7725 - accuracy: 0.5125 - val_loss: 1.8186 - val_accuracy: 0.5222
# Epoch 105/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.7716 - accuracy: 0.5145 - val_loss: 1.8435 - val_accuracy: 0.5183
# Epoch 106/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.7613 - accuracy: 0.5132 - val_loss: 1.8153 - val_accuracy: 0.5258
# Epoch 107/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.7561 - accuracy: 0.5149 - val_loss: 1.8026 - val_accuracy: 0.5304
# Epoch 108/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.7365 - accuracy: 0.5207 - val_loss: 1.7940 - val_accuracy: 0.5297
# Epoch 109/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.7568 - accuracy: 0.5116 - val_loss: 1.7889 - val_accuracy: 0.5277
# Epoch 110/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.7479 - accuracy: 0.5204 - val_loss: 1.7916 - val_accuracy: 0.5277
# Epoch 111/500
# 265/265 [==============================] - 17s 64ms/step - loss: 1.7354 - accuracy: 0.5195 - val_loss: 1.8082 - val_accuracy: 0.5238
# Epoch 112/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.7383 - accuracy: 0.5204 - val_loss: 1.8036 - val_accuracy: 0.5253
# Epoch 113/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.7131 - accuracy: 0.5255 - val_loss: 1.7906 - val_accuracy: 0.5335
# Epoch 114/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.7202 - accuracy: 0.5275 - val_loss: 1.8029 - val_accuracy: 0.5345
# Epoch 115/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.7022 - accuracy: 0.5267 - val_loss: 1.7794 - val_accuracy: 0.5318
# Epoch 116/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6946 - accuracy: 0.5263 - val_loss: 1.7694 - val_accuracy: 0.5389
# Epoch 117/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6965 - accuracy: 0.5278 - val_loss: 1.7949 - val_accuracy: 0.5290
# Epoch 118/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6742 - accuracy: 0.5346 - val_loss: 1.7703 - val_accuracy: 0.5335
# Epoch 119/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6832 - accuracy: 0.5373 - val_loss: 1.7706 - val_accuracy: 0.5394
# Epoch 120/500
# 265/265 [==============================] - 17s 66ms/step - loss: 1.6795 - accuracy: 0.5335 - val_loss: 1.8037 - val_accuracy: 0.5280
# Epoch 121/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6942 - accuracy: 0.5306 - val_loss: 1.8052 - val_accuracy: 0.5338
# Epoch 122/500
# 265/265 [==============================] - 17s 66ms/step - loss: 1.6775 - accuracy: 0.5317 - val_loss: 1.7900 - val_accuracy: 0.5318
# Epoch 123/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6578 - accuracy: 0.5366 - val_loss: 1.7992 - val_accuracy: 0.5346
# Epoch 124/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6487 - accuracy: 0.5413 - val_loss: 1.7577 - val_accuracy: 0.5386
# Epoch 125/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6261 - accuracy: 0.5454 - val_loss: 1.7738 - val_accuracy: 0.5352
# Epoch 126/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6473 - accuracy: 0.5376 - val_loss: 1.7840 - val_accuracy: 0.5328
# Epoch 127/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6246 - accuracy: 0.5493 - val_loss: 1.7724 - val_accuracy: 0.5355
# Epoch 128/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6394 - accuracy: 0.5435 - val_loss: 1.7783 - val_accuracy: 0.5346
# Epoch 129/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6517 - accuracy: 0.5379 - val_loss: 1.7611 - val_accuracy: 0.5387
# Epoch 130/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6281 - accuracy: 0.5500 - val_loss: 1.7426 - val_accuracy: 0.5426
# Epoch 131/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6257 - accuracy: 0.5437 - val_loss: 1.8116 - val_accuracy: 0.5238
# Epoch 132/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6101 - accuracy: 0.5460 - val_loss: 1.7890 - val_accuracy: 0.5335
# Epoch 133/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6088 - accuracy: 0.5523 - val_loss: 1.7804 - val_accuracy: 0.5353
# Epoch 134/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6046 - accuracy: 0.5506 - val_loss: 1.7639 - val_accuracy: 0.5382
# Epoch 135/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5996 - accuracy: 0.5526 - val_loss: 1.7797 - val_accuracy: 0.5363
# Epoch 136/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5914 - accuracy: 0.5472 - val_loss: 1.7535 - val_accuracy: 0.5438
# Epoch 137/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5808 - accuracy: 0.5592 - val_loss: 1.7722 - val_accuracy: 0.5348
# Epoch 138/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5909 - accuracy: 0.5548 - val_loss: 1.7586 - val_accuracy: 0.5438
# Epoch 139/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.6014 - accuracy: 0.5508 - val_loss: 1.7815 - val_accuracy: 0.5331
# Epoch 140/500
# 265/265 [==============================] - 18s 66ms/step - loss: 1.5930 - accuracy: 0.5537 - val_loss: 1.7974 - val_accuracy: 0.5384
# Epoch 141/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5838 - accuracy: 0.5543 - val_loss: 1.7780 - val_accuracy: 0.5408
# Epoch 142/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5781 - accuracy: 0.5584 - val_loss: 1.7692 - val_accuracy: 0.5403
# Epoch 143/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5642 - accuracy: 0.5583 - val_loss: 1.8020 - val_accuracy: 0.5324
# Epoch 144/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5703 - accuracy: 0.5609 - val_loss: 1.7999 - val_accuracy: 0.5369
# Epoch 145/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5633 - accuracy: 0.5619 - val_loss: 1.8114 - val_accuracy: 0.5341
# Epoch 146/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5567 - accuracy: 0.5603 - val_loss: 1.7861 - val_accuracy: 0.5365
# Epoch 147/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5506 - accuracy: 0.5617 - val_loss: 1.7494 - val_accuracy: 0.5445
# Epoch 148/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5497 - accuracy: 0.5654 - val_loss: 1.7638 - val_accuracy: 0.5460
# Epoch 149/500
# 265/265 [==============================] - 17s 65ms/step - loss: 1.5340 - accuracy: 0.5699 - val_loss: 1.8255 - val_accuracy: 0.5267
# Epoch 150/500
# 265/265 [==============================] - 17s 66ms/step - loss: 1.5472 - accuracy: 0.5646 - val_loss: 1.7679 - val_accuracy: 0.5426
# Test set evaluation metrics
# 30/30 [==============================] - 0s 8ms/step - loss: 1.7415 - accuracy: 0.5451
# loss: 1.74
# accuracy: 0.55

# %% [markdown]
# ### Μεταφορά μάθησης: ResNet

# %%
def init_resnet_model(summary):
    resnet_model = tf.keras.applications.resnet.ResNet50(input_shape=(img_rows, img_cols, img_channels),
                                                         include_top=False,
                                                         weights='imagenet')
    # unfreeze conv layers
    resnet_model.trainable = True
    dropout_layer = tf.keras.layers.Dropout(rate=0.7)
    dropout_layer.trainable = True
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
    global_average_layer.trainable = True
    
    # add top layer for CIFAR100 classification
    prediction_layer = tf.keras.layers.Dense(len(CIFAR100_LABELS_LIST),activation='softmax')
    model = tf.keras.Sequential([resnet_model, dropout_layer, global_average_layer, prediction_layer]) 
    model.compile(optimizer=tf.optimizers.RMSprop(learning_rate=0.0001),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=["accuracy"])
    if summary: model.summary()
    return model

# %%
RESNET_MODEL = init_resnet_model(True)
RESNET_MODEL_history = train_model(RESNET_MODEL, 500, 40, 10)
model_report(RESNET_MODEL, RESNET_MODEL_history, 30)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 1, 1, 2048)        23587712
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1, 1, 2048)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 100)               204900
# =================================================================
# Total params: 23,792,612
# Trainable params: 23,739,492
# Non-trainable params: 53,120
# _________________________________________________________________
# Epoch 1/500
# 265/265 [==============================] - 35s 95ms/step - loss: 5.9614 - accuracy: 0.0154 - val_loss: 4.6141 - val_accuracy: 0.0102
# Epoch 2/500
# 265/265 [==============================] - 24s 89ms/step - loss: 4.5189 - accuracy: 0.0707 - val_loss: 4.5803 - val_accuracy: 0.0182
# Epoch 3/500
# 265/265 [==============================] - 24s 89ms/step - loss: 3.6949 - accuracy: 0.1656 - val_loss: 3.9850 - val_accuracy: 0.1158
# Epoch 4/500
# 265/265 [==============================] - 24s 90ms/step - loss: 3.2165 - accuracy: 0.2307 - val_loss: 2.8548 - val_accuracy: 0.2969
# Epoch 5/500
# 265/265 [==============================] - 24s 89ms/step - loss: 2.9285 - accuracy: 0.2773 - val_loss: 2.3225 - val_accuracy: 0.3979
# Epoch 6/500
# 265/265 [==============================] - 24s 89ms/step - loss: 2.7518 - accuracy: 0.3057 - val_loss: 2.3139 - val_accuracy: 0.4137
# Epoch 7/500
# 265/265 [==============================] - 24s 90ms/step - loss: 2.6071 - accuracy: 0.3343 - val_loss: 2.1452 - val_accuracy: 0.4470
# Epoch 8/500
# 265/265 [==============================] - 24s 89ms/step - loss: 2.4863 - accuracy: 0.3607 - val_loss: 2.1488 - val_accuracy: 0.4477
# Epoch 9/500
# 265/265 [==============================] - 23s 88ms/step - loss: 2.4132 - accuracy: 0.3777 - val_loss: 2.1878 - val_accuracy: 0.4550
# Epoch 10/500
# 265/265 [==============================] - 24s 89ms/step - loss: 2.3231 - accuracy: 0.3967 - val_loss: 2.0010 - val_accuracy: 0.4810
# Epoch 11/500
# 265/265 [==============================] - 24s 89ms/step - loss: 2.2499 - accuracy: 0.4132 - val_loss: 2.0710 - val_accuracy: 0.4754
# Epoch 12/500
# 265/265 [==============================] - 24s 91ms/step - loss: 2.1883 - accuracy: 0.4294 - val_loss: 2.1994 - val_accuracy: 0.4761
# Epoch 13/500
# 265/265 [==============================] - 24s 90ms/step - loss: 2.1771 - accuracy: 0.4342 - val_loss: 2.1076 - val_accuracy: 0.4947
# Epoch 14/500
# 265/265 [==============================] - 24s 89ms/step - loss: 2.1433 - accuracy: 0.4410 - val_loss: 2.0339 - val_accuracy: 0.4944
# Epoch 15/500
# 265/265 [==============================] - 24s 89ms/step - loss: 2.0984 - accuracy: 0.4515 - val_loss: 4.2252 - val_accuracy: 0.5020
# Epoch 16/500
# 265/265 [==============================] - 24s 89ms/step - loss: 2.0713 - accuracy: 0.4579 - val_loss: 2.3683 - val_accuracy: 0.5100
# Epoch 17/500
# 265/265 [==============================] - 24s 90ms/step - loss: 2.0242 - accuracy: 0.4665 - val_loss: 2.2297 - val_accuracy: 0.5110
# Epoch 18/500
# 265/265 [==============================] - 24s 90ms/step - loss: 1.9939 - accuracy: 0.4804 - val_loss: 2.0721 - val_accuracy: 0.5087
# Epoch 19/500
# 265/265 [==============================] - 24s 90ms/step - loss: 1.9790 - accuracy: 0.4846 - val_loss: 2.1429 - val_accuracy: 0.5143
# Epoch 20/500
# 265/265 [==============================] - 24s 90ms/step - loss: 1.9375 - accuracy: 0.4883 - val_loss: 1.8244 - val_accuracy: 0.5421
# Epoch 21/500
# 265/265 [==============================] - 24s 90ms/step - loss: 1.8963 - accuracy: 0.5029 - val_loss: 2.1207 - val_accuracy: 0.5321
# Epoch 22/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.9007 - accuracy: 0.5020 - val_loss: 2.0489 - val_accuracy: 0.5306
# Epoch 23/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.8681 - accuracy: 0.5071 - val_loss: 1.9908 - val_accuracy: 0.5326
# Epoch 24/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.8537 - accuracy: 0.5079 - val_loss: 1.9945 - val_accuracy: 0.5408
# Epoch 25/500
# 265/265 [==============================] - 23s 88ms/step - loss: 1.8210 - accuracy: 0.5211 - val_loss: 1.8711 - val_accuracy: 0.5470
# Epoch 26/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.8113 - accuracy: 0.5217 - val_loss: 1.9623 - val_accuracy: 0.5338
# Epoch 27/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.7909 - accuracy: 0.5308 - val_loss: 2.1629 - val_accuracy: 0.5406
# Epoch 28/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.7860 - accuracy: 0.5326 - val_loss: 2.1342 - val_accuracy: 0.5362
# Epoch 29/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.7868 - accuracy: 0.5339 - val_loss: 1.9127 - val_accuracy: 0.5526
# Epoch 30/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.7512 - accuracy: 0.5358 - val_loss: 1.8880 - val_accuracy: 0.5516
# Epoch 31/500
# 265/265 [==============================] - 23s 88ms/step - loss: 1.7458 - accuracy: 0.5378 - val_loss: 1.9549 - val_accuracy: 0.5523
# Epoch 32/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.7368 - accuracy: 0.5455 - val_loss: 2.0936 - val_accuracy: 0.5459
# Epoch 33/500
# 265/265 [==============================] - 24s 90ms/step - loss: 1.7375 - accuracy: 0.5402 - val_loss: 2.4245 - val_accuracy: 0.5484
# Epoch 34/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.7106 - accuracy: 0.5469 - val_loss: 2.0731 - val_accuracy: 0.5482
# Epoch 35/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6986 - accuracy: 0.5545 - val_loss: 2.0128 - val_accuracy: 0.5472
# Epoch 36/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6834 - accuracy: 0.5566 - val_loss: 1.8132 - val_accuracy: 0.5633
# Epoch 37/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6740 - accuracy: 0.5589 - val_loss: 2.0746 - val_accuracy: 0.5360
# Epoch 38/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6475 - accuracy: 0.5663 - val_loss: 1.8981 - val_accuracy: 0.5659
# Epoch 39/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6192 - accuracy: 0.5734 - val_loss: 1.8987 - val_accuracy: 0.5603
# Epoch 40/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6546 - accuracy: 0.5656 - val_loss: 1.9930 - val_accuracy: 0.5504
# Epoch 41/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6287 - accuracy: 0.5685 - val_loss: 1.9726 - val_accuracy: 0.5511
# Epoch 42/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6309 - accuracy: 0.5759 - val_loss: 1.8804 - val_accuracy: 0.5744
# Epoch 43/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6028 - accuracy: 0.5781 - val_loss: 2.0772 - val_accuracy: 0.5516
# Epoch 44/500
# 265/265 [==============================] - 23s 88ms/step - loss: 1.5875 - accuracy: 0.5795 - val_loss: 3.0010 - val_accuracy: 0.5720
# Epoch 45/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6037 - accuracy: 0.5784 - val_loss: 2.1119 - val_accuracy: 0.5608
# Epoch 46/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.6071 - accuracy: 0.5843 - val_loss: 2.2918 - val_accuracy: 0.5603
# Epoch 47/500
# 265/265 [==============================] - 23s 88ms/step - loss: 1.5693 - accuracy: 0.5837 - val_loss: 2.2415 - val_accuracy: 0.5438
# Epoch 48/500
# 265/265 [==============================] - 23s 88ms/step - loss: 1.5709 - accuracy: 0.5829 - val_loss: 1.9218 - val_accuracy: 0.5683
# Epoch 49/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.5390 - accuracy: 0.5917 - val_loss: 2.0346 - val_accuracy: 0.5425
# Epoch 50/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.5603 - accuracy: 0.5966 - val_loss: 1.8612 - val_accuracy: 0.5693
# Epoch 51/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.5597 - accuracy: 0.5877 - val_loss: 2.1853 - val_accuracy: 0.5623
# Epoch 52/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.5527 - accuracy: 0.5988 - val_loss: 1.9334 - val_accuracy: 0.5581
# Epoch 53/500
# 265/265 [==============================] - 23s 88ms/step - loss: 1.5327 - accuracy: 0.5944 - val_loss: 1.9120 - val_accuracy: 0.5603
# Epoch 54/500
# 265/265 [==============================] - 23s 88ms/step - loss: 1.5324 - accuracy: 0.6003 - val_loss: 1.8708 - val_accuracy: 0.5727
# Epoch 55/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4942 - accuracy: 0.6044 - val_loss: 1.7788 - val_accuracy: 0.5831
# Epoch 56/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.5235 - accuracy: 0.6008 - val_loss: 1.8794 - val_accuracy: 0.5795
# Epoch 57/500
# 265/265 [==============================] - 23s 88ms/step - loss: 1.5273 - accuracy: 0.6020 - val_loss: 1.9634 - val_accuracy: 0.5700
# Epoch 58/500
# 265/265 [==============================] - 23s 88ms/step - loss: 1.4755 - accuracy: 0.6124 - val_loss: 1.9593 - val_accuracy: 0.5684
# Epoch 59/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4733 - accuracy: 0.6120 - val_loss: 2.4462 - val_accuracy: 0.5352
# Epoch 60/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4815 - accuracy: 0.6073 - val_loss: 1.8905 - val_accuracy: 0.5746
# Epoch 61/500
# 265/265 [==============================] - 23s 89ms/step - loss: 1.4501 - accuracy: 0.6144 - val_loss: 2.1200 - val_accuracy: 0.5543
# Epoch 62/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4502 - accuracy: 0.6204 - val_loss: 2.1401 - val_accuracy: 0.5579
# Epoch 63/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4728 - accuracy: 0.6177 - val_loss: 1.9632 - val_accuracy: 0.5712
# Epoch 64/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4377 - accuracy: 0.6256 - val_loss: 2.1538 - val_accuracy: 0.5746
# Epoch 65/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4131 - accuracy: 0.6237 - val_loss: 2.9812 - val_accuracy: 0.5577
# Epoch 66/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4424 - accuracy: 0.6219 - val_loss: 2.0521 - val_accuracy: 0.5630
# Epoch 67/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4313 - accuracy: 0.6260 - val_loss: 1.8627 - val_accuracy: 0.5735
# Epoch 68/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4675 - accuracy: 0.6195 - val_loss: 2.0988 - val_accuracy: 0.5708
# Epoch 69/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4047 - accuracy: 0.6291 - val_loss: 1.9396 - val_accuracy: 0.5691
# Epoch 70/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4236 - accuracy: 0.6304 - val_loss: 1.8449 - val_accuracy: 0.5864
# Epoch 71/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4155 - accuracy: 0.6348 - val_loss: 2.2061 - val_accuracy: 0.5717
# Epoch 72/500
# 265/265 [==============================] - 24s 90ms/step - loss: 1.4084 - accuracy: 0.6376 - val_loss: 1.9273 - val_accuracy: 0.5831
# Epoch 73/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.4072 - accuracy: 0.6350 - val_loss: 2.0404 - val_accuracy: 0.5861
# Epoch 74/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.3869 - accuracy: 0.6315 - val_loss: 2.0951 - val_accuracy: 0.5594
# Epoch 75/500
# 265/265 [==============================] - 24s 89ms/step - loss: 1.3907 - accuracy: 0.6365 - val_loss: 1.8279 - val_accuracy: 0.5885
# Test set evaluation metrics
# 30/30 [==============================] - 1s 17ms/step - loss: 1.7515 - accuracy: 0.5956
# loss: 1.75
# accuracy: 0.60

# %% [markdown]
# ### Μεταφορά μάθησης: DenseNet

# %%
def init_DenseNet_model(summary):
    DenseNet_MODEL=tf.keras.applications.densenet.DenseNet121(input_shape=(img_rows, img_cols, img_channels),
                                                              include_top=False,
                                                              weights='imagenet')
    # unfreeze conv layers
    DenseNet_MODEL.trainable = True

    dropout_layer = tf.keras.layers.Dropout(rate=0.5)
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
    dropout_layer.trainable = True
    global_average_layer.trainable = True
    
    # add top layer for CIFAR100 classification
    prediction_layer = tf.keras.layers.Dense(len(CIFAR100_LABELS_LIST), activation='softmax')
    model = tf.keras.Sequential([DenseNet_MODEL, dropout_layer, global_average_layer, prediction_layer])

    model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=["accuracy"])
    if summary: model.summary()
    return model

# %%
DenseNet_MODEL = init_DenseNet_model(summary = True)
DenseNet_MODEL_history = train_model(DenseNet_MODEL, 500, 30, 5)
model_report(DenseNet_MODEL, DenseNet_MODEL_history, 30)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Functional)     (None, 1, 1, 1024)        7037504
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 1, 1, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               102500
# =================================================================
# Total params: 7,140,004
# Trainable params: 7,056,356
# Non-trainable params: 83,648
# _________________________________________________________________
# Epoch 1/500
# 265/265 [==============================] - 35s 91ms/step - loss: 5.1705 - accuracy: 0.0256 - val_loss: 3.9337 - val_accuracy: 0.1663
# Epoch 2/500
# 265/265 [==============================] - 22s 82ms/step - loss: 3.8640 - accuracy: 0.1240 - val_loss: 2.9126 - val_accuracy: 0.2947
# Epoch 3/500
# 265/265 [==============================] - 22s 82ms/step - loss: 3.1765 - accuracy: 0.2302 - val_loss: 2.3410 - val_accuracy: 0.3867
# Epoch 4/500
# 265/265 [==============================] - 22s 82ms/step - loss: 2.7815 - accuracy: 0.2988 - val_loss: 2.0804 - val_accuracy: 0.4472
# Epoch 5/500
# 265/265 [==============================] - 22s 82ms/step - loss: 2.5006 - accuracy: 0.3513 - val_loss: 1.9248 - val_accuracy: 0.4711
# Epoch 6/500
# 265/265 [==============================] - 22s 81ms/step - loss: 2.3458 - accuracy: 0.3908 - val_loss: 1.8682 - val_accuracy: 0.4873
# Epoch 7/500
# 265/265 [==============================] - 22s 82ms/step - loss: 2.2218 - accuracy: 0.4162 - val_loss: 1.7485 - val_accuracy: 0.5160
# Epoch 8/500
# 265/265 [==============================] - 22s 82ms/step - loss: 2.0658 - accuracy: 0.4468 - val_loss: 1.6900 - val_accuracy: 0.5299
# Epoch 9/500
# 265/265 [==============================] - 22s 81ms/step - loss: 1.9797 - accuracy: 0.4727 - val_loss: 1.6273 - val_accuracy: 0.5489
# Epoch 10/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.8946 - accuracy: 0.4891 - val_loss: 1.6093 - val_accuracy: 0.5543
# Epoch 11/500
# 265/265 [==============================] - 22s 83ms/step - loss: 1.8418 - accuracy: 0.5027 - val_loss: 1.5808 - val_accuracy: 0.5627
# Epoch 12/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.7529 - accuracy: 0.5240 - val_loss: 1.5429 - val_accuracy: 0.5751
# Epoch 13/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.6946 - accuracy: 0.5366 - val_loss: 1.5550 - val_accuracy: 0.5718
# Epoch 14/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.6406 - accuracy: 0.5524 - val_loss: 1.5073 - val_accuracy: 0.5810
# Epoch 15/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.6164 - accuracy: 0.5547 - val_loss: 1.4638 - val_accuracy: 0.5934
# Epoch 16/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.5475 - accuracy: 0.5732 - val_loss: 1.5613 - val_accuracy: 0.5786
# Epoch 17/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.5358 - accuracy: 0.5763 - val_loss: 1.4525 - val_accuracy: 0.5971
# Epoch 18/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.4906 - accuracy: 0.5884 - val_loss: 1.5339 - val_accuracy: 0.5837
# Epoch 19/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.4282 - accuracy: 0.5999 - val_loss: 1.5360 - val_accuracy: 0.5859
# Epoch 20/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.3920 - accuracy: 0.6112 - val_loss: 1.3711 - val_accuracy: 0.6135
# Epoch 21/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.3759 - accuracy: 0.6172 - val_loss: 1.4050 - val_accuracy: 0.6123
# Epoch 22/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.3457 - accuracy: 0.6241 - val_loss: 1.4904 - val_accuracy: 0.5943
# Epoch 23/500
# 265/265 [==============================] - 22s 83ms/step - loss: 1.3232 - accuracy: 0.6225 - val_loss: 1.5007 - val_accuracy: 0.5988
# Epoch 24/500
# 265/265 [==============================] - 22s 81ms/step - loss: 1.2671 - accuracy: 0.6429 - val_loss: 1.4092 - val_accuracy: 0.6199
# Epoch 25/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.2401 - accuracy: 0.6489 - val_loss: 1.3895 - val_accuracy: 0.6189
# Epoch 26/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.2190 - accuracy: 0.6548 - val_loss: 1.3932 - val_accuracy: 0.6209
# Epoch 27/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.1908 - accuracy: 0.6636 - val_loss: 1.3299 - val_accuracy: 0.6362
# Epoch 28/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.1614 - accuracy: 0.6710 - val_loss: 1.3852 - val_accuracy: 0.6140
# Epoch 29/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.1378 - accuracy: 0.6737 - val_loss: 1.3496 - val_accuracy: 0.6298
# Epoch 30/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.1324 - accuracy: 0.6804 - val_loss: 1.3958 - val_accuracy: 0.6197
# Epoch 31/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.0974 - accuracy: 0.6836 - val_loss: 1.3268 - val_accuracy: 0.6362
# Epoch 32/500
# 265/265 [==============================] - 22s 81ms/step - loss: 1.0735 - accuracy: 0.6927 - val_loss: 1.4192 - val_accuracy: 0.6185
# Epoch 33/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.0455 - accuracy: 0.6988 - val_loss: 1.3600 - val_accuracy: 0.6357
# Epoch 34/500
# 265/265 [==============================] - 22s 83ms/step - loss: 1.0355 - accuracy: 0.7016 - val_loss: 1.3491 - val_accuracy: 0.6350
# Epoch 35/500
# 265/265 [==============================] - 22s 82ms/step - loss: 1.0017 - accuracy: 0.7083 - val_loss: 1.4081 - val_accuracy: 0.6248
# Epoch 36/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.9884 - accuracy: 0.7140 - val_loss: 1.3737 - val_accuracy: 0.6333
# Epoch 37/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.9672 - accuracy: 0.7182 - val_loss: 1.4342 - val_accuracy: 0.6197
# Epoch 38/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.9274 - accuracy: 0.7283 - val_loss: 1.4554 - val_accuracy: 0.6146
# Epoch 39/500
# 265/265 [==============================] - 22s 83ms/step - loss: 0.9346 - accuracy: 0.7307 - val_loss: 1.4206 - val_accuracy: 0.6248
# Epoch 40/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.9073 - accuracy: 0.7369 - val_loss: 1.4213 - val_accuracy: 0.6340
# Epoch 41/500
# 265/265 [==============================] - 22s 83ms/step - loss: 0.8988 - accuracy: 0.7389 - val_loss: 1.4463 - val_accuracy: 0.6279
# Epoch 42/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.8714 - accuracy: 0.7449 - val_loss: 1.3831 - val_accuracy: 0.6333
# Epoch 43/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.8525 - accuracy: 0.7524 - val_loss: 1.3987 - val_accuracy: 0.6365
# Epoch 44/500
# 265/265 [==============================] - 22s 81ms/step - loss: 0.8304 - accuracy: 0.7587 - val_loss: 1.3561 - val_accuracy: 0.6457
# Epoch 45/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.8250 - accuracy: 0.7590 - val_loss: 1.4407 - val_accuracy: 0.6301
# Epoch 46/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.7841 - accuracy: 0.7675 - val_loss: 1.4607 - val_accuracy: 0.6252
# Epoch 47/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.7798 - accuracy: 0.7667 - val_loss: 1.4506 - val_accuracy: 0.6282
# Epoch 48/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.7862 - accuracy: 0.7707 - val_loss: 1.5130 - val_accuracy: 0.6225
# Epoch 49/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.7488 - accuracy: 0.7771 - val_loss: 1.4764 - val_accuracy: 0.6287
# Epoch 50/500
# 265/265 [==============================] - 22s 81ms/step - loss: 0.7557 - accuracy: 0.7792 - val_loss: 1.4968 - val_accuracy: 0.6264
# Epoch 51/500
# 265/265 [==============================] - 22s 82ms/step - loss: 0.7306 - accuracy: 0.7850 - val_loss: 1.4691 - val_accuracy: 0.6354
# Test set evaluation metrics
# 30/30 [==============================] - 1s 17ms/step - loss: 1.3340 - accuracy: 0.6357
# loss: 1.33
# accuracy: 0.64

# %% [markdown]
# ## Σύγκριση ακρίβειας μοντέλων

# %%
plt.figure(figsize=(12,8))

barWidth = 0.30
models = ['From Scratch', 'ResNet', 'DenseNet']

twenty = [0.66, 0.67, 0.77]
eighty = [0.55, 0.60, 0.64]

r1 = np.arange(3)
r2 = [x + barWidth for x in r1]

plt.bar(r1, twenty, color='darkslateblue', width=barWidth, label='20 Classes')
plt.bar(r2, eighty, color='darkred', width=barWidth, label='80 Classes')
plt.xticks([r + barWidth/2 for r in range(3)], models)
plt.ylim(bottom=0.1)
plt.title("Validation Accuracy for the 3 optimized models")
plt.ylabel("Validation Accuracy")
plt.legend(loc=2)
plt.grid(axis="y", linestyle="--")

plt.savefig('./models.png')
plt.show()
